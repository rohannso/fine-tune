# %%
import os
from typing import Optional
from serpapi import SerpApiClient
from langchain.pydantic_v1 import BaseModel, Field
from langchain_core.tools import tool
from dotenv import load_dotenv
load_dotenv()


# (Your Pydantic models FlightsInput and FlightsInputSchema remain the same)
class FlightsInput(BaseModel):
    departure_airport: Optional[str] = Field(description='Departure airport code (IATA)')
    arrival_airport: Optional[str] = Field(description='Arrival airport code (IATA)')
    outbound_date: Optional[str] = Field(description='Parameter defines the outbound date. The format is YYYY-MM-DD. e.g. 2024-06-22')
    return_date: Optional[str] = Field(description='Parameter defines the return date. The format is YYYY-MM-DD. e.g. 2024-06-28')
    adults: Optional[int] = Field(1, description='Parameter defines the number of adults. Default to 1.')
    children: Optional[int] = Field(0, description='Parameter defines the number of children. Default to 0.')
    infants_in_seat: Optional[int] = Field(0, description='Parameter defines the number of infants in seat. Default to 0.')
    infants_on_lap: Optional[int] = Field(0, description='Parameter defines the number of infants on lap. Default to 0.')

class FlightsInputSchema(BaseModel):
    params: FlightsInput


@tool(args_schema=FlightsInputSchema)
def flights_finder(params: FlightsInput):
    '''
    Find flights using the Google Flights engine.

    Returns:
        dict: Flight search results.
    '''

    api_params = {
        'api_key': os.getenv('SERPAPI_API_KEY'),
        'engine': 'google_flights',
        'hl': 'en',
        'gl': 'us',
        'departure_id': params.departure_airport,
        'arrival_id': params.arrival_airport,
        'outbound_date': params.outbound_date,
        'return_date': params.return_date,
        'currency': 'USD',
        'adults': params.adults,
        'infants_in_seat': params.infants_in_seat,
        'stops': '1',
        'infants_on_lap': params.infants_on_lap,
        'children': params.children
    }

    try:
        client = SerpApiClient(api_params)
        search_results = client.get_dict()

        # --- NEW: Check for an explicit error message from the API ---
        if 'error' in search_results:
            return f"An API error occurred: {search_results['error']}"

        # --- IMPROVED: Check for the key before trying to access it ---
        if 'best_flights' in search_results:
            return search_results['best_flights']
        else:
            # Provide a clear, helpful message if no flights are found
            return "No flights were found for the specified criteria. Please try different dates or airports."

    except Exception as e:
        # Fallback for other unexpected errors
        return f"An unexpected error occurred: {str(e)}"

# %%
flights_finder({
  "params": {
    "departure_airport": "LHR",
    "arrival_airport": "DXB",
    "outbound_date": "2026-04-10",
    "return_date": "2026-04-24",
    "adults": 2,
    "children": 1,
    "infants_in_seat": 1
  }
})
# Out:
# [{'flights': [{'departure_airport': {'name': 'Heathrow Airport',
#      'id': 'LHR',
#      'time': '2026-04-10 21:30'},
#     'arrival_airport': {'name': 'Dubai International Airport',
#      'id': 'DXB',
#      'time': '2026-04-11 07:35'},
#     'duration': 425,
#     'airplane': 'Boeing 787-10',
#     'airline': 'British Airways',
#     'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/BA.png',
#     'travel_class': 'Economy',
#     'flight_number': 'BA 109',
#     'legroom': '31 in',
#     'extensions': ['Average legroom (31 in)',
#      'Wi-Fi for a fee',
#      'In-seat power & USB outlets',
#      'On-demand video',
#      'Carbon emissions estimate: 1174 kg'],
#     'overnight': True}],
#   'total_duration': 425,
#   'carbon_emissions': {'this_flight': 1175000,
#    'typical_for_this_route': 1537000,
#    'difference_percent': -24},
#   'price': 2395,
#   'type': 'Round trip',
#   'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/BA.png',
#   'departure_token': 'WyJDalJJWlUxcGFXRTBUa042Y2pSQlEwWkpWRkZDUnkwdExTMHRMUzB0TFc5clltcGhNVUZCUVVGQlIybDNRMnByU0VwT1QzZEJFZ1ZDUVRFd09Sb0xDUHZPRGhBQ0dnTlZVMFE0SEhEN3pnND0iLFtbIkxIUiIsIjIwMjYtMDQtMTAiLCJEWEIiLG51bGwsIkJBIiwiMTA5Il1dXQ=='},
#  {'flights': [{'departure_airport': {'name': 'Heathrow Airport',
#      'id': 'LHR',
#      'time': '2026-04-10 22:30'},
#     'arrival_airport': {'name': 'Dubai International Airport',
#      'id': 'DXB',
#      'time': '2026-04-11 08:30'},
#     'duration': 420,
#     'airplane': 'Boeing 777',
#     'airline': 'British Airways',
#     'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/BA.png',
#     'travel_class': 'Economy',
#     'flight_number': 'BA 105',
#     'legroom': '31 in',
#     'extensions': ['Average legroom (31 in)',
#      'Wi-Fi for a fee',
#      'In-seat USB outlet',
#      'On-demand video',
#      'Carbon emissions estimate: 1672 kg'],
#     'overnight': True}],
#   'total_duration': 420,
#   'carbon_emissions': {'this_flight': 1673000,
#    'typical_for_this_route': 1537000,
#    'difference_percent': 9},
#   'price': 2579,
#   'type': 'Round trip',
#   'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/BA.png',
#   'departure_token': 'WyJDalJJWlUxcGFXRTBUa042Y2pSQlEwWkpWRkZDUnkwdExTMHRMUzB0TFc5clltcGhNVUZCUVVGQlIybDNRMnByU0VwT1QzZEJFZ1ZDUVRFd05Sb0xDTExlRHhBQ0dnTlZVMFE0SEhDeTNnOD0iLFtbIkxIUiIsIjIwMjYtMDQtMTAiLCJEWEIiLG51bGwsIkJBIiwiMTA1Il1dXQ=='},
#  {'flights': [{'departure_airport': {'name': 'Heathrow Airport',
#      'id': 'LHR',
#      'time': '2026-04-10 16:50'},
#     'arrival_airport': {'name': 'Dubai International Airport',
#      'id': 'DXB',
#      'time': '2026-04-11 02:45'},
#     'duration': 415,
#     'airplane': 'Airbus A380',
#     'airline': 'Emirates',
#     'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/EK.png',
#     'travel_class': 'Economy',
#     'flight_number': 'EK 30',
#     'legroom': '32 in',
#     'extensions': ['Above average legroom (32 in)',
#      'Wi-Fi for a fee',
#      'In-seat power & USB outlets',
#      'On-demand video',
#      'Carbon emissions estimate: 1527 kg'],
#     'overnight': True}],
#   'total_duration': 415,
#   'carbon_emissions': {'this_flight': 1527000,
#    'typical_for_this_route': 1537000,
#    'difference_percent': -1},
#   'price': 2808,
#   'type': 'Round trip',
#   'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/EK.png',
#   'departure_token': 'WyJDalJJWlUxcGFXRTBUa042Y2pSQlEwWkpWRkZDUnkwdExTMHRMUzB0TFc5clltcGhNVUZCUVVGQlIybDNRMnByU0VwT1QzZEJFZ1JGU3pNd0dnc0kwcEVSRUFJYUExVlRSRGdjY05LUkVRPT0iLFtbIkxIUiIsIjIwMjYtMDQtMTAiLCJEWEIiLG51bGwsIkVLIiwiMzAiXV1d'}]

# %%
import os
from typing import Optional

# --- Import the specific client from the serpapi library ---
from serpapi import SerpApiClient
from langchain.pydantic_v1 import BaseModel, Field
from langchain_core.tools import tool

class HotelsInput(BaseModel):
    q: str = Field(description='Location of the hotel (e.g., "Miami Beach, Florida")')
    check_in_date: str = Field(description='Check-in date. The format is YYYY-MM-DD. e.g. 2025-11-20')
    check_out_date: str = Field(description='Check-out date. The format is YYYY-MM-DD. e.g. 2025-11-25')
    # --- Changed default to a string for robustness ---
    sort_by: Optional[str] = Field("8", description='Parameter for sorting results. Default is "8" for highest rating.')
    adults: Optional[int] = Field(1, description='Number of adults. Default to 1.')
    children: Optional[int] = Field(0, description='Number of children. Default to 0.')
    rooms: Optional[int] = Field(1, description='Number of rooms. Default to 1.')
    hotel_class: Optional[str] = Field(
        None, description='Filter by hotel class (e.g., "2,3,4" for 2, 3, and 4-star hotels).')

class HotelsInputSchema(BaseModel):
    params: HotelsInput

@tool(args_schema=HotelsInputSchema)
def hotels_finder(params: HotelsInput):
    '''
    Find hotels using the Google Hotels engine.

    Returns:
        dict or str: Hotel search results or an error message.
    '''
    # --- Renamed to api_params to avoid confusion with the input 'params' object ---
    api_params = {
        'api_key': os.environ.get('SERPAPI_API_KEY'),
        'engine': 'google_hotels',
        'hl': 'en',
        'gl': 'in',
        'q': params.q,
        'check_in_date': params.check_in_date,
        'check_out_date': params.check_out_date,
        'currency': 'INR',
        'adults': params.adults,
        'children': params.children,
        'rooms': params.rooms,
        'sort_by': params.sort_by,
        'hotel_class': params.hotel_class
    }

    try:
        # --- Use the modern, class-based method for the API call ---
        client = SerpApiClient(api_params)
        search_results = client.get_dict()

        # --- 1. Check for an explicit error message from the API ---
        if 'error' in search_results:
            return f"An API error occurred: {search_results['error']}"

        # --- 2. Check for the 'properties' key before trying to access it ---
        if 'properties' in search_results and search_results['properties']:
            # Return the top 5 results if they exist
            return search_results['properties'][:5]
        else:
            # --- 3. Provide a clear, helpful message if no hotels are found ---
            return "No hotels were found for the specified criteria. Please try different dates or locations."

    except Exception as e:
        # --- 4. Fallback for other unexpected errors (e.g., network issues) ---
        return f"An unexpected error occurred: {str(e)}"

# %%
hotels_finder({
  "params": {
    "q": "Eiffel Tower, Paris, France",
    "check_in_date": "2025-11-10",
    "check_out_date": "2025-11-15",
    "adults": 2
  }
})
# Out:
# [{'type': 'hotel',
#   'name': 'Hôtel Tourisme Avenue',
#   'description': 'Relaxed hotel offering bright rooms with free Wi-Fi, plus a terrace with seating.',
#   'link': 'https://www.hoteltourismeavenue.com/',
#   'property_token': 'ChgI5PP_6eWyk5b8ARoLL2cvMXRmX2dxdjIQAQ',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2025-11-10&check_out_date=2025-11-15&children=0&currency=INR&engine=google_hotels&gl=in&hl=en&property_token=ChgI5PP_6eWyk5b8ARoLL2cvMXRmX2dxdjIQAQ&q=Eiffel+Tower%2C+Paris%2C+France&sort_by=8',
#   'gps_coordinates': {'latitude': 48.8496072, 'longitude': 2.2983252},
#   'check_in_time': '3:00\u202fPM',
#   'check_out_time': '12:00\u202fPM',
#   'rate_per_night': {'lowest': '₹18,079',
#    'extracted_lowest': 18079,
#    'before_taxes_fees': '₹15,014',
#    'extracted_before_taxes_fees': 15014},
#   'total_rate': {'lowest': '₹90,396',
#    'extracted_lowest': 90396,
#    'before_taxes_fees': '₹75,068',
#    'extracted_before_taxes_fees': 75068},
#   'nearby_places': [{'name': 'Eiffel Tower',
#     'transportations': [{'type': 'Public transport', 'duration': '8 min'}]},
#    {'name': 'La Motte - Picquet Grenelle',
#     'transportations': [{'type': 'Walking', 'duration': '2 min'}]},
#    {'name': 'Paris Charles de Gaulle Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '42 min'},
#      {'type': 'Public transport', 'duration': '56 min'}]},
#    {'name': 'LA GAULOISE PARIS',
#     'transportations': [{'type': 'Walking', 'duration': '1 min'}]}],
#   'hotel_class': '4-star tourist hotel',
#   'extracted_hotel_class': 4,
#   'images': [{'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipP5PHg0sQItYn3SZwmlij9-nEaeqHeDuJmTg8EK=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipP5PHg0sQItYn3SZwmlij9-nEaeqHeDuJmTg8EK=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPeV7D18R-jk_alXT5cQana93Jvj9KuIKLNLnHB=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPeV7D18R-jk_alXT5cQana93Jvj9KuIKLNLnHB=s10000'},
#    {'thumbnail': 'https://lh6.googleusercontent.com/proxy/0WAm8eLfNcFz7r3kOjSlPVl-KmH43pJOrHZDyyiAyL00wi8n64ClXVNKpzkAZPhXpH0gtu3fzO0pU_cfL-jEsZk16g9qS00v-dPjCV5tpgQ2Y6w_hRxhOLOzehT7gnW24_6eZUAT5WVffN7SF6nrY0RP8zq0qA=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://images.trvl-media.com/lodging/7000000/6290000/6282000/6281972/d0026677_z.jpg'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNE7Qap1SPJ2jvG9DxmHLHHXP0XNfagoF0j6HnR=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNE7Qap1SPJ2jvG9DxmHLHHXP0XNfagoF0j6HnR=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPdqJi7VSPPlD9Xsz3tN43ZOYMJEKCaNTL6uvON=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPdqJi7VSPPlD9Xsz3tN43ZOYMJEKCaNTL6uvON=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPw5234O48akLIueS7wFQOtnksG7t9Qfs01r-Hi=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPw5234O48akLIueS7wFQOtnksG7t9Qfs01r-Hi=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipM5whuNIP8GTP0gyWpYd9oYFKQv-JXbhP1cmTEe=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipM5whuNIP8GTP0gyWpYd9oYFKQv-JXbhP1cmTEe=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/proxy/Htau1lb0c1wJ5s818OKLQvzBDvC8vnyIF6OHAuQ2sRMyDiSBycpTMTm1mM0W0T4MCS9PUwVhBsQoCyUdOmaPnfzXKNSs0KABBQ_9TWq6OSd8by0poL_Z7lbPIHx92-RAzUekG5Y4aZtC5z-F43OF2f9tRGmjhQ=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://images.trvl-media.com/lodging/7000000/6290000/6282000/6281972/42f12a1c_z.jpg'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/proxy/LYTUInCgqenP2twsaLC0iAqynaIAiZBqYKPqtAg0m4y18z6QC6f4p3BMCSFAKwLaxvZY_faoe7rkvKNduPzkUyRW-yTL0WkZ2BYEHiLwhIhSfYHqqc3hpugR9iq8Wvv-aD5PhWwRmOfFczHNo6ZYsXenq-H4NA=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://images.trvl-media.com/lodging/7000000/6290000/6282000/6281972/c05d6617_z.jpg'}],
#   'overall_rating': 4.8,
#   'reviews': 2834,
#   'ratings': [{'stars': 5, 'count': 2423},
#    {'stars': 4, 'count': 282},
#    {'stars': 3, 'count': 80},
#    {'stars': 2, 'count': 11},
#    {'stars': 1, 'count': 38}],
#   'location_rating': 4.3,
#   'reviews_breakdown': [{'name': 'Location',
#     'description': 'Location',
#     'total_mentioned': 378,
#     'positive': 341,
#     'negative': 10,
#     'neutral': 27},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 355,
#     'positive': 332,
#     'negative': 18,
#     'neutral': 5},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 389,
#     'positive': 346,
#     'negative': 26,
#     'neutral': 17},
#    {'name': 'Transport',
#     'description': 'Public transit',
#     'total_mentioned': 119,
#     'positive': 95,
#     'negative': 3,
#     'neutral': 21},
#    {'name': 'Cleanliness',
#     'description': 'Cleanliness',
#     'total_mentioned': 214,
#     'positive': 198,
#     'negative': 9,
#     'neutral': 7},
#    {'name': 'Breakfast',
#     'description': 'Breakfast',
#     'total_mentioned': 120,
#     'positive': 99,
#     'negative': 16,
#     'neutral': 5}],
#   'amenities': ['Breakfast ($)',
#    'Free Wi-Fi',
#    'Pool',
#    'Air conditioning',
#    'Bar',
#    'Restaurant',
#    'Room service',
#    'Airport shuttle',
#    'Full-service laundry',
#    'Accessible',
#    'Kid-friendly',
#    'Smoke-free property']},
#  {'type': 'hotel',
#   'name': 'Hôtel de Londres Eiffel',
#   'description': 'Elegant rooms with free Wi-Fi & designer toiletries, plus a guest lounge lined with books.',
#   'link': 'http://www.hotel-paris-londres-eiffel.com/',
#   'property_token': 'ChgIls_T-Ne7wZkUGgwvZy8xMmxzcjgwY3AQAQ',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2025-11-10&check_out_date=2025-11-15&children=0&currency=INR&engine=google_hotels&gl=in&hl=en&property_token=ChgIls_T-Ne7wZkUGgwvZy8xMmxzcjgwY3AQAQ&q=Eiffel+Tower%2C+Paris%2C+France&sort_by=8',
#   'gps_coordinates': {'latitude': 48.8578544, 'longitude': 2.3017488},
#   'check_in_time': '3:00\u202fPM',
#   'check_out_time': '11:30\u202fAM',
#   'rate_per_night': {'lowest': '₹26,216',
#    'extracted_lowest': 26216,
#    'before_taxes_fees': '₹22,265',
#    'extracted_before_taxes_fees': 22265},
#   'total_rate': {'lowest': '₹1,31,079',
#    'extracted_lowest': 131079,
#    'before_taxes_fees': '₹1,11,324',
#    'extracted_before_taxes_fees': 111324},
#   'deal': '21% less than usual',
#   'deal_description': 'Deal',
#   'nearby_places': [{'name': 'Eiffel Tower',
#     'transportations': [{'type': 'Walking', 'duration': '7 min'}]},
#    {'name': 'École Militaire',
#     'transportations': [{'type': 'Walking', 'duration': '8 min'}]},
#    {'name': 'Paris Charles de Gaulle Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '41 min'},
#      {'type': 'Public transport', 'duration': '1 hr 7 min'}]},
#    {'name': 'Le comptoir de la traboule',
#     'transportations': [{'type': 'Walking', 'duration': '1 min'}]}],
#   'hotel_class': '4-star tourist hotel',
#   'extracted_hotel_class': 4,
#   'images': [{'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPoL4NGIE5tYRN8jTT199xxDwq4zBz9vfPuRr6q=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPoL4NGIE5tYRN8jTT199xxDwq4zBz9vfPuRr6q=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipP70_m1AQTLAHjIZxtPMDazcrgADZgbJJcYxV8f=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipP70_m1AQTLAHjIZxtPMDazcrgADZgbJJcYxV8f=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNOhYaGSU7zi5E4uNe_BkbZFsnOvaglQHWKUK2G=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNOhYaGSU7zi5E4uNe_BkbZFsnOvaglQHWKUK2G=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipP_npjSfb-qzyntNUe1jNEO-2l4M0sjpwUCxxha=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipP_npjSfb-qzyntNUe1jNEO-2l4M0sjpwUCxxha=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNBymUiUcQbLWNRrybzCOWKBHTQFBnXB0OeafCM=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNBymUiUcQbLWNRrybzCOWKBHTQFBnXB0OeafCM=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipOxL0Sjt3z3f8TKrKhaK1Rbv6tfvCBhvKP2AQjO=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOxL0Sjt3z3f8TKrKhaK1Rbv6tfvCBhvKP2AQjO=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMfP5Inn9v4AaHc95WYsDRPaGgwQ4lstLDGxthq=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMfP5Inn9v4AaHc95WYsDRPaGgwQ4lstLDGxthq=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipOmhbPstFx2_TvabD6daz75U8wX-dricadVUqsA=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOmhbPstFx2_TvabD6daz75U8wX-dricadVUqsA=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMTZM-Ee2xm37P2S1hFmrj_cfgWw01OWqAL7fk_=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMTZM-Ee2xm37P2S1hFmrj_cfgWw01OWqAL7fk_=s10000'}],
#   'overall_rating': 4.8,
#   'reviews': 664,
#   'ratings': [{'stars': 5, 'count': 604},
#    {'stars': 4, 'count': 39},
#    {'stars': 3, 'count': 6},
#    {'stars': 2, 'count': 6},
#    {'stars': 1, 'count': 9}],
#   'location_rating': 4.8,
#   'reviews_breakdown': [{'name': 'Pets',
#     'description': 'Pets',
#     'total_mentioned': 17,
#     'positive': 13,
#     'negative': 1,
#     'neutral': 3},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 337,
#     'positive': 331,
#     'negative': 6,
#     'neutral': 0},
#    {'name': 'Family',
#     'description': 'Family friendly',
#     'total_mentioned': 50,
#     'positive': 44,
#     'negative': 0,
#     'neutral': 6},
#    {'name': 'Location',
#     'description': 'Location',
#     'total_mentioned': 274,
#     'positive': 264,
#     'negative': 1,
#     'neutral': 9},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 280,
#     'positive': 259,
#     'negative': 9,
#     'neutral': 12},
#    {'name': 'Breakfast',
#     'description': 'Breakfast',
#     'total_mentioned': 112,
#     'positive': 104,
#     'negative': 3,
#     'neutral': 5}],
#   'amenities': ['Breakfast ($)',
#    'Free Wi-Fi',
#    'Parking ($)',
#    'Air conditioning',
#    'Pet-friendly',
#    'Airport shuttle',
#    'Business center',
#    'Kid-friendly',
#    'Smoke-free property']},
#  {'type': 'hotel',
#   'name': 'Shangri-La Paris',
#   'description': 'Elegant rooms & suites in a luxe lodging offering Eiffel Tower views, a renowned restaurant & a spa.',
#   'link': 'http://www.shangri-la.com/paris/',
#   'property_token': 'ChgIoLGshZia7u0RGgwvZy8xaGJfaDlfeGQQAQ',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2025-11-10&check_out_date=2025-11-15&children=0&currency=INR&engine=google_hotels&gl=in&hl=en&property_token=ChgIoLGshZia7u0RGgwvZy8xaGJfaDlfeGQQAQ&q=Eiffel+Tower%2C+Paris%2C+France&sort_by=8',
#   'gps_coordinates': {'latitude': 48.863927999999994,
#    'longitude': 2.2934026999999997},
#   'check_in_time': '3:00\u202fPM',
#   'check_out_time': '12:00\u202fPM',
#   'rate_per_night': {'lowest': '₹1,50,100',
#    'extracted_lowest': 150100,
#    'before_taxes_fees': '₹1,33,560',
#    'extracted_before_taxes_fees': 133560},
#   'total_rate': {'lowest': '₹7,50,498',
#    'extracted_lowest': 750498,
#    'before_taxes_fees': '₹6,67,800',
#    'extracted_before_taxes_fees': 667800},
#   'nearby_places': [{'name': 'Eiffel Tower',
#     'transportations': [{'type': 'Public transport', 'duration': '3 min'}]},
#    {'name': 'Paris Charles de Gaulle Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '35 min'},
#      {'type': 'Public transport', 'duration': '1 hr 4 min'}]},
#    {'name': 'Le New York',
#     'transportations': [{'type': 'Walking', 'duration': '4 min'}]}],
#   'hotel_class': '5-star tourist hotel',
#   'extracted_hotel_class': 5,
#   'images': [{'thumbnail': 'https://lh5.googleusercontent.com/proxy/n4YmOJp0-dldW1DtSDfYQ8J3LN0RyLHWtL18_bSptq8PoYZ-bIcLSzf5KdhuJAWJ--z5bfJi90nvMyPkYDOlp98LGdvaG_ZUzHhiuSGR93SZ3qde5eMCSBKvQs21qFYiS69ESJKjAd89ZIqZq0YFD0Kpj4WdLJg=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://photos.hotelbeds.com/giata/original/33/332588/332588a_hb_ro_079.jpg'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPNM1gfPLzfSCG2eul_J8l8c17SGjMwonEjqyav=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPNM1gfPLzfSCG2eul_J8l8c17SGjMwonEjqyav=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipOVBUc1QycqvdfbUs1eRDCi0KvGDTNqtTUD2Z6x=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOVBUc1QycqvdfbUs1eRDCi0KvGDTNqtTUD2Z6x=s10000'},
#    {'thumbnail': 'https://lh4.googleusercontent.com/proxy/xC4PGLcBd9UTRgkWta-4FL4ELXRVw61hhtnXg-teiz8NLyMIri4zBeDWIv2KMDn6L4ngmh6f6C1Ky6kWMcdap-XcJ-8HqqbTsJh0ZKGgK9GBEMGlEpIcsurcp-FyAUAb-zY7bgrjSsPzvwwMH45b-9-3ndT6BlU=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://www.iceportal.com/data/2813-73936-f74694665_XXLejpg/France/Paris/Shangri-La-Paris/Photo/Shangri-La-Paris-Paris-Undefined-Shangri-La-Hotel-Paris-Lobby.jpg'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/proxy/y2dDsQ6RURAx3DpHG0fukPrRjtdFzQjBEksz9d0qOIqQOpkCcAgrq1iQvNVFypU5mV02M35tmgZDczD7zHfShCoquKO1PzlOeTIMp4MPdottMsUElcnktyjq21UT0QbDrN3LUnHmM1llgK0M9c-g_znTDYpi3_o=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://i.giatamedia.com/m.php?m=AQABAAAAla4KAO9hWgQFAAttNxtbKmb3u9qPpeoqPpk'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPYWQzU-Oi7GM3Qndk0iHRZ7-A18UZukAfcM4dO=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPYWQzU-Oi7GM3Qndk0iHRZ7-A18UZukAfcM4dO=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipOMLukNajsLlQYzdUUcJ9sn30MRICTYz7DyDY63=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOMLukNajsLlQYzdUUcJ9sn30MRICTYz7DyDY63=s10000'},
#    {'thumbnail': 'https://lh4.googleusercontent.com/proxy/F6WgGJ4eYZTsTbJmnJr6HWLHU27klMWLLMsZcXKKcHQ5OriUXRDFSXRlt9cK-fFN8_aftXfn6q_amKDOp-Qjv0RY7bI30OF4OkJxzAvZgbUK1PjUncAWPA7Lvnjxid6zcpEJ-u3VKb4qeloduUaMO1G1HjX9-w=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://photos.hotelbeds.com/giata/original/33/332588/332588a_hb_ro_078.jpg'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipOOUsx1ZlYkOF577Fb8mDFNrqlAA1Rb0prdKPWG=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOOUsx1ZlYkOF577Fb8mDFNrqlAA1Rb0prdKPWG=s10000'}],
#   'overall_rating': 4.7,
#   'reviews': 3281,
#   'ratings': [{'stars': 5, 'count': 2754},
#    {'stars': 4, 'count': 322},
#    {'stars': 3, 'count': 80},
#    {'stars': 2, 'count': 36},
#    {'stars': 1, 'count': 89}],
#   'location_rating': 4.4,
#   'reviews_breakdown': [{'name': 'Wellness',
#     'description': 'Wellness',
#     'total_mentioned': 47,
#     'positive': 39,
#     'negative': 6,
#     'neutral': 2},
#    {'name': 'Spa',
#     'description': 'Spa',
#     'total_mentioned': 40,
#     'positive': 35,
#     'negative': 4,
#     'neutral': 1},
#    {'name': 'Couples',
#     'description': 'Couple friendly',
#     'total_mentioned': 41,
#     'positive': 38,
#     'negative': 1,
#     'neutral': 2},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 476,
#     'positive': 431,
#     'negative': 36,
#     'neutral': 9},
#    {'name': 'Bar',
#     'description': 'Bar or lounge',
#     'total_mentioned': 137,
#     'positive': 107,
#     'negative': 17,
#     'neutral': 13},
#    {'name': 'Dining',
#     'description': 'Food and Beverage',
#     'total_mentioned': 159,
#     'positive': 117,
#     'negative': 26,
#     'neutral': 16}],
#   'amenities': ['Breakfast',
#    'Free Wi-Fi',
#    'Parking',
#    'Indoor pool',
#    'Hot tub',
#    'Air conditioning',
#    'Pet-friendly',
#    'Fitness center',
#    'Spa',
#    'Bar',
#    'Restaurant',
#    'Room service',
#    'Airport shuttle',
#    'Full-service laundry',
#    'Accessible',
#    'Business center',
#    'Kid-friendly']},
#  {'type': 'hotel',
#   'name': 'Hotel du Champ de Mars',
#   'description': 'Relaxed hotel offering cozy rooms with flat-screens & free WiFi, plus a warm lobby & breakfast (fee).',
#   'link': 'http://www.hotelduchampdemars.com/',
#   'property_token': 'ChgIno2AxoD0sOeGARoLL2cvMXRjd3FmemoQAQ',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2025-11-10&check_out_date=2025-11-15&children=0&currency=INR&engine=google_hotels&gl=in&hl=en&property_token=ChgIno2AxoD0sOeGARoLL2cvMXRjd3FmemoQAQ&q=Eiffel+Tower%2C+Paris%2C+France&sort_by=8',
#   'gps_coordinates': {'latitude': 48.856378, 'longitude': 2.3060964999999998},
#   'check_out_time': '11:00\u202fAM',
#   'rate_per_night': {'lowest': '₹30,983',
#    'extracted_lowest': 30983,
#    'before_taxes_fees': '₹27,142',
#    'extracted_before_taxes_fees': 27142},
#   'total_rate': {'lowest': '₹1,54,913',
#    'extracted_lowest': 154913,
#    'before_taxes_fees': '₹1,35,708',
#    'extracted_before_taxes_fees': 135708},
#   'nearby_places': [{'name': "Musée d'Orsay",
#     'transportations': [{'type': 'Taxi', 'duration': '9 min'}]},
#    {'name': 'Paris Charles de Gaulle Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '44 min'},
#      {'type': 'Public transport', 'duration': '1 hr 3 min'}]},
#    {'name': 'Via Del Campo',
#     'transportations': [{'type': 'Walking', 'duration': '2 min'}]}],
#   'hotel_class': '3-star tourist hotel',
#   'extracted_hotel_class': 3,
#   'images': [{'thumbnail': 'https://lh6.googleusercontent.com/proxy/M88yjJci9OS-Ic0hxPVEzbir--RpKQnBzL7_8-pzpnkKvzYkIYcm3GYHTlHnMRu8QqyNocpqHyboPbJrenYWVI3cenFeoBZSS3CAU0JssJPiqfAij8boTwSD0ObrBm6FbHzCZtbTdC8vCxUCY5uJ_Dbw4iv63g=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/06/46/6f/89/hotel-du-champ-de-mars.jpg?w=1800&h=1200&s=1'},
#    {'thumbnail': 'https://lh6.googleusercontent.com/proxy/52WpSn8fpW6SzUDE1GxxWYu868-yKOONua5-9j8tY-v9FasjmuoJbFrSp80H8mAQsDOHY5-pJzSU9CwxiVtm2UN7rBJHBKsC2dL2Sq_qOw57ZKF5thPXYNNCd0FT0FaXB-4-qGR2wxi0iqSTJI4yQHVOf3aOsg=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/06/46/6e/c0/hotel-du-champ-de-mars.jpg?w=1800&h=1200&s=1'},
#    {'thumbnail': 'https://lh4.googleusercontent.com/proxy/ssamuonhadU8hZHvgy3oLn9U9dWdO1ClNUsHB6u2WRFnqHZRjYToejPOutSz_stuO5L_ky10jAvfgW-QcqyjCgeIn238viw9lgZejIV4RC3TJ3N6sEaLsKaAOQRfdke3PSLrQJrNVD5k4wCPDhU5fqMVySoKxg=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/06/46/6f/23/hotel-du-champ-de-mars.jpg?w=1800&h=1200&s=1'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipM9nNYQmfH_iucT1ekpUt58GJ2-bZ8aBGrwsdej=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipM9nNYQmfH_iucT1ekpUt58GJ2-bZ8aBGrwsdej=s10000'},
#    {'thumbnail': 'https://lh4.googleusercontent.com/proxy/MK5mJUwjOeayLfSMAFp-K3YmF_BQNezHNA3r0XVQ8nq0OQiqCD9GuPVdaesWR5PqJaACyzDtkbw0j7ykbyuz885pF_4ZI0YRk9evfme4b4ug3fLmUe5oqrNMNSK2AFWkNX-r2nAmN84PRY0b7cF_jZR-NSu5Tfk=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/06/46/6f/e6/hotel-du-champ-de-mars.jpg?w=1800&h=1200&s=1'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipOoma65Y7ieIQrZCRHL-cinUigZD2xdHx47NrjE=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOoma65Y7ieIQrZCRHL-cinUigZD2xdHx47NrjE=s10000'},
#    {'thumbnail': 'https://lh6.googleusercontent.com/proxy/6DUvQHvtJdfvzi7zqg3AqffH5hbIL-SdkNnHtDPzkmcPkCxwPojWAmkRbn8EbLc7T4dFfrIT6cic-zFNKZjKc9n1BJJLCAhcfDWozioX0LkwxiSeEx9lFdrdADx19t7e0rYW1L79--4QDm1tKMYeCGJMvXQbtHg=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/06/46/70/18/hotel-du-champ-de-mars.jpg?w=1800&h=1200&s=1'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/gps-cs-s/AC9h4np8W1ALbFOPO7toU9vM7DJjQSdC_-huVNbz-kAgjFHZenFj3A_EqHxwlk32x_OpT70JeJPQnCyVsephX6Hrb_mWBiunYO7ltBqVG-fuOM0TjZodSraygGoDq2dJ2MSqEd8LxVe6=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/CIHM0ogKEICAgIDfv72KLQ=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/gps-cs-s/AC9h4noDh3VzNCsgjSStTTZFnLeWbP2gdPPMHV7DNPI1e9pblhH5PzWis9fC3sSCawsH3S841e18fIaVwIY1kajAajzQdZGQBvMOcoKI7lVyM-tK1UPly9S24t0LxibWMhUEuoSwz3NC=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/CIHM0ogKEICAgIDDlobmKg=s10000'}],
#   'overall_rating': 4.7,
#   'reviews': 420,
#   'ratings': [{'stars': 5, 'count': 336},
#    {'stars': 4, 'count': 63},
#    {'stars': 3, 'count': 13},
#    {'stars': 2, 'count': 1},
#    {'stars': 1, 'count': 7}],
#   'location_rating': 4.9,
#   'reviews_breakdown': [{'name': 'Location',
#     'description': 'Location',
#     'total_mentioned': 115,
#     'positive': 110,
#     'negative': 0,
#     'neutral': 5},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 111,
#     'positive': 106,
#     'negative': 3,
#     'neutral': 2},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 117,
#     'positive': 109,
#     'negative': 5,
#     'neutral': 3},
#    {'name': 'Cleanliness',
#     'description': 'Cleanliness',
#     'total_mentioned': 58,
#     'positive': 56,
#     'negative': 1,
#     'neutral': 1},
#    {'name': 'Transport',
#     'description': 'Public transit',
#     'total_mentioned': 26,
#     'positive': 24,
#     'negative': 1,
#     'neutral': 1},
#    {'name': 'Family',
#     'description': 'Family friendly',
#     'total_mentioned': 6,
#     'positive': 5,
#     'negative': 0,
#     'neutral': 1}],
#   'amenities': ['Breakfast',
#    'Free Wi-Fi',
#    'Air conditioning',
#    'Pet-friendly',
#    'Airport shuttle',
#    'Smoke-free property']},
#  {'type': 'hotel',
#   'name': 'Hôtel Plaza Athénée',
#   'description': 'Stately hotel featuring 5 restaurants & a bar, plus a spa, a gym & views of the Eiffel Tower.',
#   'link': 'https://www.dorchestercollection.com/paris/hotel-plaza-athenee',
#   'property_token': 'ChcI-6i_l_nu1O-mARoKL20vMDI3Z3B2dBAB',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2025-11-10&check_out_date=2025-11-15&children=0&currency=INR&engine=google_hotels&gl=in&hl=en&property_token=ChcI-6i_l_nu1O-mARoKL20vMDI3Z3B2dBAB&q=Eiffel+Tower%2C+Paris%2C+France&sort_by=8',
#   'gps_coordinates': {'latitude': 48.8662354, 'longitude': 2.3043736999999997},
#   'check_in_time': '3:00\u202fPM',
#   'check_out_time': '12:00\u202fPM',
#   'rate_per_night': {'lowest': '₹2,06,371',
#    'extracted_lowest': 206371,
#    'before_taxes_fees': '₹1,84,728',
#    'extracted_before_taxes_fees': 184728},
#   'total_rate': {'lowest': '₹10,31,857',
#    'extracted_lowest': 1031857,
#    'before_taxes_fees': '₹9,23,642',
#    'extracted_before_taxes_fees': 923642},
#   'nearby_places': [{'name': 'Arc de Triomphe',
#     'transportations': [{'type': 'Taxi', 'duration': '7 min'}]},
#    {'name': 'Franklin D. Roosevelt',
#     'transportations': [{'type': 'Walking', 'duration': '8 min'}]},
#    {'name': 'Paris Charles de Gaulle Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '38 min'},
#      {'type': 'Public transport', 'duration': '56 min'}]},
#    {'name': 'L’Alsace',
#     'transportations': [{'type': 'Walking', 'duration': '9 min'}]}],
#   'hotel_class': '5-star tourist hotel',
#   'extracted_hotel_class': 5,
#   'images': [{'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPE1ASyNkz7P4C51nd_z-BhrDUwkGE7RDESVAFq=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPE1ASyNkz7P4C51nd_z-BhrDUwkGE7RDESVAFq=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNL1tcMnAHuVsEHsgHSkTDaS7ye2foC-4Omm4c5=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNL1tcMnAHuVsEHsgHSkTDaS7ye2foC-4Omm4c5=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPNrGLPgYG7jILf-fz5vGzzGDEuCE2C9AdOHUJ3=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPNrGLPgYG7jILf-fz5vGzzGDEuCE2C9AdOHUJ3=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMHbkVz38P1SmBTDJGYRVzccJeH3UUoEBIx--Rs=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMHbkVz38P1SmBTDJGYRVzccJeH3UUoEBIx--Rs=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipN0GXF9zK9SL2_TmXUvDjiiJWOYKxzQM0Soj57t=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipN0GXF9zK9SL2_TmXUvDjiiJWOYKxzQM0Soj57t=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNb6vUc96oAgg_6Vz43LgYceg3s5BZWZRCgEiUk=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNb6vUc96oAgg_6Vz43LgYceg3s5BZWZRCgEiUk=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipO6Phu-1zLIAhNpXw68CvVdjrOLO_jC7DYjM5JL=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipO6Phu-1zLIAhNpXw68CvVdjrOLO_jC7DYjM5JL=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPblrXlEd1QX5B9gaugJWF4d6Tqtiswxog8CljN=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPblrXlEd1QX5B9gaugJWF4d6Tqtiswxog8CljN=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPRr-O9Q6AFt9uCl1eLB2-umWNVGotw1L9bwXor=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPRr-O9Q6AFt9uCl1eLB2-umWNVGotw1L9bwXor=s10000'}],
#   'overall_rating': 4.6,
#   'reviews': 2844,
#   'ratings': [{'stars': 5, 'count': 2314},
#    {'stars': 4, 'count': 298},
#    {'stars': 3, 'count': 71},
#    {'stars': 2, 'count': 39},
#    {'stars': 1, 'count': 122}],
#   'location_rating': 4.7,
#   'reviews_breakdown': [{'name': 'Dining',
#     'description': 'Food and Beverage',
#     'total_mentioned': 123,
#     'positive': 93,
#     'negative': 18,
#     'neutral': 12},
#    {'name': 'Bar',
#     'description': 'Bar or lounge',
#     'total_mentioned': 101,
#     'positive': 68,
#     'negative': 19,
#     'neutral': 14},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 313,
#     'positive': 250,
#     'negative': 53,
#     'neutral': 10},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 282,
#     'positive': 253,
#     'negative': 18,
#     'neutral': 11},
#    {'name': 'Couples',
#     'description': 'Couple friendly',
#     'total_mentioned': 14,
#     'positive': 13,
#     'negative': 1,
#     'neutral': 0},
#    {'name': 'Wellness',
#     'description': 'Wellness',
#     'total_mentioned': 11,
#     'positive': 11,
#     'negative': 0,
#     'neutral': 0}],
#   'amenities': ['Breakfast ($)',
#    'Free Wi-Fi',
#    'Free parking',
#    'Air conditioning',
#    'Pet-friendly',
#    'Fitness center',
#    'Spa',
#    'Bar',
#    'Restaurant',
#    'Room service',
#    'Airport shuttle',
#    'Full-service laundry',
#    'Accessible',
#    'Business center',
#    'Kid-friendly']}]

# %%
import os
from typing import TypedDict, Annotated, Optional, List
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_core.tools import tool
from langchain.pydantic_v1 import BaseModel, Field
# --- Import ChatGroq instead of ChatOpenAI ---
from langchain_groq import ChatGroq
from langgraph.graph import StateGraph, END
# --- Import ToolNode and remove ToolExecutor ---
from langgraph.prebuilt import ToolNode
from serpapi import SerpApiClient
from dotenv import load_dotenv
load_dotenv()
from tools import flights_finder as ff, hotel_finder as hf

# %%
tools = [ff, hf]

# --- Define the LLM using Groq ---
model = ChatGroq(temperature=0, model_name="llama3-70b-8192")
model = model.bind_tools(tools)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 5
#       3 # --- Define the LLM using Groq ---
#       4 model = ChatGroq(temperature=0, model_name="llama3-70b-8192")
# ----> 5 model = model.bind_tools(tools)
#
# File c:\Users\r\OneDrive\Desktop\ai trip planner\.venv\Lib\site-packages\langchain_groq\chat_models.py:825, in ChatGroq.bind_tools(self, tools, tool_choice, **kwargs)
#     800 def bind_tools(
#     801     self,
#     802     tools: Sequence[Union[dict[str, Any], type[BaseModel], Callable, BaseTool]],
#    (...)    807     **kwargs: Any,
#     808 ) -> Runnable[LanguageModelInput, BaseMessage]:
#     809     """Bind tool-like objects to this chat model.
#     810
#     811     Args:
#    (...)    823
#     824     """
# --> 825     formatted_tools = [convert_to_openai_tool(tool) for tool in tools]
#     826     if tool_choice is not None and tool_choice:
#     827         if tool_choice == "any":
#
# File c:\Users\r\OneDrive\Desktop\ai trip planner\.venv\Lib\site-packages\langchain_core\utils\function_calling.py:595, in convert_to_openai_tool(tool, strict)
#     593         oai_tool["format"] = tool.metadata["format"]
#     594     return oai_tool
# --> 595 oai_function = convert_to_openai_function(tool, strict=strict)
#     596 return {"type": "function", "function": oai_function}
#
# File c:\Users\r\OneDrive\Desktop\ai trip planner\.venv\Lib\site-packages\langchain_core\utils\function_calling.py:486, in convert_to_openai_function(function, strict)
#     479 else:
#     480     msg = (
#     481         f"Unsupported function\n\n{function}\n\nFunctions must be passed in"
#     482         " as Dict, pydantic.BaseModel, or Callable. If they're a dict they must"
#     483         " either be in OpenAI function format or valid JSON schema with top-level"
#     484         " 'title' and 'description' keys."
#     485     )
# --> 486     raise ValueError(msg)
#     488 if strict is not None:
#     489     if "strict" in oai_function and oai_function["strict"] != strict:
#
# ValueError: Unsupported function
#
# <module 'tools.flights_finder' from 'c:\\Users\\r\\OneDrive\\Desktop\\ai trip planner\\tools\\flights_finder.py'>
#
# Functions must be passed in as Dict, pydantic.BaseModel, or Callable. If they're a dict they must either be in OpenAI function format or valid JSON schema with top-level 'title' and 'description' keys.
